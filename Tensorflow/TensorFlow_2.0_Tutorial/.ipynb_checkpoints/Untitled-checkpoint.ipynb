# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

import tensorflow as tf
from tensorflow import keras

# helper library
import numpy as np
import matplotlib.pyplot as plt

# https://www.tensorflow.org/tutorials/keras/text_classification_with_hub?hl=ko

# %% [markdown]
# # 1. 기본 이미지 분류

# %%
fashion_mnist=keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()

# %%
type(train_images)
# Out:
# numpy.ndarray

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(5,5))
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 정규화
train_images=train_images/255.0
test_images=test_images/255.0

# %%
plt.figure(figsize=(7,7))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    # 784 -> 128
    keras.layers.Dense(128,activation='relu'),
    # 128 -> 10
    keras.layers.Dense(10,activation='softmax')
])

# %%
# optimizer, loss 설정
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',matrics=['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.4977
# Epoch 2/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.3761
# Epoch 3/5
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.3381
# Epoch 4/5
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.3159
# Epoch 5/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.2972

# %%
# 정확도 평가
# verbose : 학습중 풀력되는 문구 
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\n테스트 정확도:', test_acc)
# Out:
# 10000/1 - 0s - loss: 0.2949
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-78a7ab2ce9aa> in <module>
#       1 # 정확도 평가
#       2 # verbose : 학습중 풀력되는 문구
# ----> 3 test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
#       4
#       5 print('\n테스트 정확도:', test_acc)
#
# TypeError: 'numpy.float64' object is not iterable

# %%
predictions=model.predict(test_images)

# %%
# 10개의 카테고리의 prediction 결과
predictions[0]
# Out:
# array([3.7639846e-05, 5.4908622e-07, 8.7618437e-06, 6.9143859e-08,
#        2.1371505e-05, 1.0807744e-02, 6.1996208e-05, 2.5497084e-02,
#        3.1818543e-04, 9.6324658e-01], dtype=float32)

# %%
print('prediction : {}, real : {}'.format(np.argmax(predictions[0]),test_labels[0]))
# Out:
# prediction : 9, real : 9

# %%
def plot_image(i,predictions_array,true_label,img):
    predictions_array,true_label,img=predictions_array[i],true_label[i],img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img,cmap=plt.cm.binary)
    predicted_label=np.argmax(predictions_array)
    if(predicted_label==true_label):
        color='blue'
    else:
        color='red'
        
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)
plt.show()

# %% [markdown]
# # 2. 영화 리뷰 텍스트 분류

# %%
# 영화 리뷰 텍스트

import tensorflow_hub as hub
import tensorflow_datasets as tfds

print("버전: ", tf.__version__)
print("즉시 실행 모드: ", tf.executing_eagerly())
print("허브 버전: ", hub.__version__)
print("GPU ", "사용 가능" if tf.config.experimental.list_physical_devices("GPU") else "사용 불가능")
# Out:
# 버전:  2.0.0
# 즉시 실행 모드:  True
# 허브 버전:  0.4.0
# GPU  사용 불가능

# %%
imdb = keras.datasets.imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 2s 0us/step

# %%
print("훈련샘플 : {}, 레이블 : {}".format(len(train_data),len(train_labels)))
# Out:
# 훈련샘플 : 25000, 레이블 : 25000

# %%
print(len(train_data[0]))
# Out:
# 218

# %%
print(len(train_data[2]))
# Out:
# 141

# %%
# 단어와 정수 인덱스를 매핑한 딕셔너리
word_index=imdb.get_word_index()

# 처음 몇 개 인덱스는 사전에 정의되어 있습니다
